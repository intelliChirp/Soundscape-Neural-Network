# %%
from preprocess import *
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D, LSTM, Activation
from keras.utils import to_categorical
import wandb
from wandb.keras import WandbCallback
import matplotlib.pyplot as plt
import sklearn.metrics as metrics

# %%
wandb.init()
config = wandb.config

config.max_len = 21
config.buckets = 50

# Save data to array file first
save_data_to_array(max_len=config.max_len, n_mfcc=config.buckets)

#labels=np.array(["chirping_birds", "crickets", "crow", 
#                 "frog", "insects"])
labels=np.array(["GOC", "GRA", "GST", 
                 "GWG", "GWC"])
# Out:
#                 Logging results to <a href="https://wandb.com" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://app.wandb.ai/joshekruse/intellichirp-snaw-NN" target="_blank">https://app.wandb.ai/joshekruse/intellichirp-snaw-NN</a><br/>
#                 Run page: <a href="https://app.wandb.ai/joshekruse/intellichirp-snaw-NN/runs/3bvsoh13" target="_blank">https://app.wandb.ai/joshekruse/intellichirp-snaw-NN/runs/3bvsoh13</a><br/>
# Saving vectors of label - 'chirping_birds': 100%|██████████████████████████████████████| 40/40 [00:01<00:00, 38.71it/s]
# Saving vectors of label - 'crickets': 100%|████████████████████████████████████████████| 40/40 [00:00<00:00, 49.76it/s]
# Saving vectors of label - 'crow': 100%|████████████████████████████████████████████████| 40/40 [00:01<00:00, 38.64it/s]
# Saving vectors of label - 'frog': 100%|████████████████████████████████████████████████| 40/40 [00:00<00:00, 65.97it/s]
# Saving vectors of label - 'insects': 100%|█████████████████████████████████████████████| 40/40 [00:00<00:00, 47.98it/s]

# %%
# Loading train/test set
X_train, X_test, X_val, y_train, y_test, y_val = get_train_test()

# %%
# Setting channels to 1 to generalize stereo sound to 1 channel
channels = 1
config.epochs = 50
config.batch_size = 100

# Number of classes
num_classes = 5

# Reshape X_train and X_test to include a 4th dimension (channels)
X_train = X_train.reshape(X_train.shape[0], config.buckets, config.max_len, channels)
X_test = X_test.reshape(X_test.shape[0], config.buckets, config.max_len, channels)
X_val = X_val.reshape(X_val.shape[0], config.buckets, config.max_len, channels)

# %%
# Spectrogram visualized of 0th element
print(X_train.shape)
#plt.imshow(X_train[500, :, :, 0])
# Out:
# (96, 50, 21, 1)

# %%
# Getting vector number where each number corresponds to a label
y_train_hot = to_categorical(y_train)
y_test_hot = to_categorical(y_test)
y_val_hot = to_categorical(y_val)

# %%
# Building the model
model = Sequential()

input_shape= (config.buckets, config.max_len, channels)

model.add(Conv2D(24, (3, 3), strides=(1, 1), input_shape=input_shape))
model.add(MaxPooling2D((2, 2), strides=(2, 2)))
model.add(Activation('relu'))

model.add(Conv2D(48, (3, 3), padding="valid"))
model.add(MaxPooling2D((2, 2), strides=(2, 2)))
model.add(Activation('relu'))

model.add(Conv2D(48, (3, 1), padding="valid"))
model.add(Activation('relu'))

model.add(Flatten())
model.add(Dropout(rate=0.5))

model.add(Dense(64))
model.add(Activation('relu'))
model.add(Dropout(rate=0.5))

model.add(Dense(len(labels)))
model.add(Activation('softmax'))
model.summary()
# Conv2D: 
#    Filters: 32
#    Kernel_size: (3,3) (height/width of the 2D convolution window)     
'''model.add(Conv2D(32, (3, 3),
    input_shape=(config.buckets, config.max_len, channels),
    activation='relu'))

model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())

model.add(Dense(128, activation='relu'))
model.add(Dense(num_classes, activation='softmax'))'''

# %%
# Configure CNN for training
model.compile(loss="categorical_crossentropy",
                  optimizer="adam",
                  metrics=['accuracy'])

# %%
wandb.init()
print(y_train_hot.shape)
print(labels.shape)
print(X_train.shape)
# Train the CNN model
#    X_train: Input data
#    y_train_hot: Target data
model.fit(X_train, y_train_hot, epochs=config.epochs, validation_data=(X_val, y_val_hot), callbacks=[WandbCallback(data_type="image", labels=labels)])
# Out:
#                 Logging results to <a href="https://wandb.com" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://app.wandb.ai/joshekruse/intellichirp-snaw-NN" target="_blank">https://app.wandb.ai/joshekruse/intellichirp-snaw-NN</a><br/>
#                 Run page: <a href="https://app.wandb.ai/joshekruse/intellichirp-snaw-NN/runs/vqjl9pd7" target="_blank">https://app.wandb.ai/joshekruse/intellichirp-snaw-NN/runs/vqjl9pd7</a><br/>
# (96, 5)
# (5,)
# (96, 50, 21, 1)
# Train on 96 samples, validate on 64 samples
# Epoch 1/50
# 96/96 [==============================] - ETA: 0s - loss: 12.3566 - accuracy: 0.156 - ETA: 0s - loss: 22.6483 - accuracy: 0.187 - 1s 9ms/step - loss: 30.0931 - accuracy: 0.2292 - val_loss: 42.3951 - val_accuracy: 0.2344
# Epoch 2/50
# 96/96 [==============================] - ETA: 0s - loss: 34.5338 - accuracy: 0.218 - 0s 1ms/step - loss: 30.5762 - accuracy: 0.2396 - val_loss: 33.7867 - val_accuracy: 0.1875
# Epoch 3/50
# 96/96 [==============================] - ETA: 0s - loss: 24.4182 - accuracy: 0.281 - ETA: 0s - loss: 24.8215 - accuracy: 0.250 - 0s 2ms/step - loss: 20.8693 - accuracy: 0.3229 - val_loss: 11.2099 - val_accuracy: 0.3281
# Epoch 4/50
# 96/96 [==============================] - ETA: 0s - loss: 6.7312 - accuracy: 0.50 - 0s 1ms/step - loss: 5.5244 - accuracy: 0.4167 - val_loss: 4.3417 - val_accuracy: 0.3125
# Epoch 5/50
# 96/96 [==============================] - ETA: 0s - loss: 4.9719 - accuracy: 0.31 - ETA: 0s - loss: 4.0261 - accuracy: 0.34 - 0s 3ms/step - loss: 3.6570 - accuracy: 0.3750 - val_loss: 3.0360 - val_accuracy: 0.3594
# Epoch 6/50
# 96/96 [==============================] - ETA: 0s - loss: 1.9051 - accuracy: 0.56 - ETA: 0s - loss: 1.2787 - accuracy: 0.65 - 0s 2ms/step - loss: 1.7945 - accuracy: 0.5938 - val_loss: 2.5044 - val_accuracy: 0.5000
# Epoch 7/50
# 96/96 [==============================] - ETA: 0s - loss: 1.5721 - accuracy: 0.71 - ETA: 0s - loss: 1.4439 - accuracy: 0.70 - 0s 1ms/step - loss: 1.3947 - accuracy: 0.6771 - val_loss: 2.1096 - val_accuracy: 0.5312
# Epoch 8/50
# 96/96 [==============================] - ETA: 0s - loss: 1.2588 - accuracy: 0.59 - ETA: 0s - loss: 1.0164 - accuracy: 0.65 - 0s 2ms/step - loss: 0.8686 - accuracy: 0.6875 - val_loss: 1.8174 - val_accuracy: 0.5469
# Epoch 9/50
# 96/96 [==============================] - ETA: 0s - loss: 0.4098 - accuracy: 0.84 - ETA: 0s - loss: 0.6221 - accuracy: 0.76 - 0s 2ms/step - loss: 0.6230 - accuracy: 0.7604 - val_loss: 1.4813 - val_accuracy: 0.5312
[==============================] - ETA: 0s - loss: 0.0110 - accuracy: 1.00 - ETA: 0s - loss: 0.0127 - accuracy: 1.00 - 0s 2ms/step - loss: 0.0158 - accuracy: 1.0000 - val_loss: 1.6682 - val_accuracy: 0.6094
# Epoch 46/50
# 96/96 [==============================] - ETA: 0s - loss: 0.0119 - accuracy: 1.00 - ETA: 0s - loss: 0.0132 - accuracy: 1.00 - 0s 2ms/step - loss: 0.0152 - accuracy: 1.0000 - val_loss: 1.6700 - val_accuracy: 0.6094
# Epoch 47/50
# 96/96 [==============================] - ETA: 0s - loss: 0.0152 - accuracy: 1.00 - ETA: 0s - loss: 0.0154 - accuracy: 1.00 - 0s 3ms/step - loss: 0.0148 - accuracy: 1.0000 - val_loss: 1.6863 - val_accuracy: 0.6250
# Epoch 48/50
# 96/96 [==============================] - ETA: 0s - loss: 0.0198 - accuracy: 1.00 - ETA: 0s - loss: 0.0164 - accuracy: 1.00 - 0s 3ms/step - loss: 0.0142 - accuracy: 1.0000 - val_loss: 1.6835 - val_accuracy: 0.6250
# Epoch 49/50
# 96/96 [==============================] - ETA: 0s - loss: 0.0178 - accuracy: 1.00 - ETA: 0s - loss: 0.0157 - accuracy: 1.00 - 0s 2ms/step - loss: 0.0137 - accuracy: 1.0000 - val_loss: 1.6908 - val_accuracy: 0.6250
# Epoch 50/50
# 96/96 [==============================] - ETA: 0s - loss: 0.0174 - accuracy: 1.00 - ETA: 0s - loss: 0.0139 - accuracy: 1.00 - 0s 2ms/step - loss: 0.0132 - accuracy: 1.0000 - val_loss: 1.6979 - val_accuracy: 0.6250

# %%
# Save the keras model
model.save("ant_cnn_model.h5")
print("Model has been saved.")
# Out:
# Model has been saved.

# %% [markdown]
# ## Running the IntelliChirp Biophony CNN

# %%
from keras.models import load_model

# Load the model
loaded_model = load_model('ant_cnn_model.h5')

# %%
# Summarize the model
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_7 (Conv2D)            (None, 48, 19, 32)        320
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 24, 9, 32)         0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 6912)              0
# _________________________________________________________________
# dense_5 (Dense)              (None, 128)               884864
# _________________________________________________________________
# dense_6 (Dense)              (None, 5)                 645
# =================================================================
# Total params: 885,829
# Trainable params: 885,829
# Non-trainable params: 0
# _________________________________________________________________

# %%
y_pred_ohe = loaded_model.predict(X_test)  # shape=(n_samples, 12)
y_pred_labels = np.argmax(y_pred_ohe, axis=1)  # only necessary if output has one-hot-encoding, shape=(n_samples)

confusion_matrix = metrics.confusion_matrix(y_true=y_test, y_pred=y_pred_labels)  # shape
print(confusion_matrix)

for class_i in range(len(labels)) :
    indices = np.argwhere(y_test == class_i)
    sum = 0
    for index in indices:
        sum += (y_test[index] == y_pred_labels[index])
    print("Accuracy for class", labels[class_i], ":", sum/len(indices))

print("Overall Accuracy :", np.mean(y_test == y_pred_labels))

'''Accuracy for class chirping_birds : [0.8]
Accuracy for class crickets : [0.25]
Accuracy for class crow : [0.83333333]
Accuracy for class frog : [0.3]
Accuracy for class insects : [0.85714286]
Overall Accuracy : 0.525'''
# Out:
# [[2 1 1 0 1]
#  [5 6 0 0 1]
#  [0 0 6 0 0]
#  [1 0 6 3 0]
#  [0 0 0 0 7]]
# Accuracy for class chirping_birds : [0.4]
# Accuracy for class crickets : [0.5]
# Accuracy for class crow : [1.]
# Accuracy for class frog : [0.3]
# Accuracy for class insects : [1.]
# Overall Accuracy : 0.6
# 'Accuracy for class chirping_birds : [0.8]\nAccuracy for class crickets : [0.25]\nAccuracy for class crow : [0.83333333]\nAccuracy for class frog : [0.3]\nAccuracy for class insects : [0.85714286]\nOverall Accuracy : 0.525'

# %%
## Running the model

n_mfcc = config.buckets
max_len = config.max_len
# convert file to wav2mfcc
# Mel-frequency cepstral coefficients
file_path = "./prediction/nature_sc.wav"
big_wave, sr = librosa.load(file_path, mono=True, sr=None)
#print(wave.shape, sr)

classification = []

for sec_index in range( int(big_wave.shape[0] / sr) ) :
    start_sec = sec_index
    end_sec = sec_index + 1
    
    sec_to_trim = np.array( [ float(start_sec), float(end_sec) ] )
    print(sec_to_trim)
    sec_to_trim = np.ceil( sec_to_trim * sr )

    wave = big_wave[int(sec_to_trim[0]) : int(sec_to_trim[1])]
    print(wave)

    wave = np.asfortranarray(wave[::3])
    mfcc = librosa.feature.mfcc(wave, sr=16000, n_mfcc=n_mfcc)

    # If maximum length exceeds mfcc lengths then pad the remaining ones
    if (max_len > mfcc.shape[1]):
        pad_width = max_len - mfcc.shape[1]
        mfcc = np.pad(mfcc, pad_width=((0, 0), (0, pad_width)), mode='constant')

    # Else cutoff the remaining parts
    else:
        mfcc = mfcc[:, :max_len]

    # Convert wav to MFCC
    prediction_data = wav2mfcc('./prediction/nature_sc.wav')
    prediction_data = mfcc
    print(prediction_data.shape)
    #print(wav2mfcc())
    # Reshape to 4 dimensions
    prediction_data = prediction_data.reshape(1, config.buckets, config.max_len, channels)
    #prediction_data = prediction_data.reshape(1, 20, config.max_len, channels)

    # Run the model on the inputted file
    predicted = loaded_model.predict(prediction_data)

    # Output the prediction values for each class
    print ('PREDICTED VALUES')
    labels_indices = range(len(labels))
    max_value = 0
    max_value_index = 0
    for index in labels_indices:
        print('\n', labels[index], ": ", '%.08f' % predicted[0,index])
        if predicted[0,index] > max_value:
            max_value_index = index
            max_value = predicted[0,index]

    # Output the prediction
    if max_value < 0.5:
        print("GUESS: Nothing")
        classification.append( { "class" : "Nothing", "timestamp" : start_sec } )
    else:
        print('\n\nGUESS: ', labels[max_value_index])
        classification.append( { "class" : labels[max_value_index], "timestamp" : start_sec } )

print(classification)
# Out:
# [0. 1.]
# [ 0.0000000e+00  1.5258789e-05  0.0000000e+00 ...  3.3020020e-02
#   1.2680054e-02 -8.7432861e-03]
# (50, 21)
# PREDICTED VALUES
#
#  chirping_birds :  0.30736196
#
#  crickets :  0.64452684
#
#  crow :  0.01276931
#
#  frog :  0.00179228
#
#  insects :  0.03354968
#
#
# GUESS:  crickets
# [1. 2.]
# [-0.03717041 -0.05769348 -0.06455994 ...  0.01766968  0.01895142
#   0.01779175]
# (50, 21)
# PREDICTED VALUES
#
#  chirping_birds :  0.23428890
#
#  crickets :  0.62110490
#
#  crow :  0.02115585
#
#  frog :  0.00654036
#
#  insects :  0.11690991
#
#
# GUESS:  crickets
# [2. 3.]
# [ 0.02345276  0.02101135  0.01712036 ... -0.01161194 -0.0141449
#  -0.01431274]
# (50, 21)
# PREDICTED VALUES
#
#  chirping_birds :  0.36313936
#
#  crickets :  0.43238679
#
#  crow :  0.02465060
#
#  frog :  0.01954458
#
#  insects :  0.16027857
# GUESS: Nothing
# [3. 4.]
# [-0.01583862 -0.01066589 -0.00762939 ... -0.0377655  -0.03556824
#  -0.02685547]
# (50, 21)
# PREDICTED VALUES
#
#  chirping_birds :  0.82177597
#
#  crickets :  0.12068707
#
#  crow :  0.00271698
#
#  frog :  0.01081211
#
#  insects :  0.04400776
#
#
# GUESS:  chirping_birds
# [4. 5.]
# [-0.02836609 -0.02510071 -0.02012634 ...  0.0138855  -0.00386047
#  -0.00904846]
# (50, 21)
# PREDICTED VALUES
#
#  chirping_birds :  0.43418595
#
#  crickets :  0.52303767
#
#  crow :  0.00231720
#
#  frog :  0.00827136
#
#  insects :  0.03218783
#
#
# GUESS:  crickets
# [5. 6.]
# [-0.00526428  0.00822449  0.01951599 ...  0.02729797  0.02156067
#   0.01234436]
# (50, 21)
# PREDICTED VALUES
#
#  chirping_birds :  0.18931797
#
#  crickets :  0.60449505
#
#  crow :  0.05825778
#
#  frog :  0.00837774
#
#  insects :  0.13955152
#
#
# GUESS:  crickets
# [6. 7.]
# [ 0.00544739  0.00053406  0.00970459 ... -0.02848816 -0.01611328
#  -0.01091003]
# (50, 21)
# PREDICTED VALUES
#
#  chirping_birds :  0.36643389
#
#  crickets :  0.60323685
#
#  crow :  0.00337125
#
#  frog :  0.00471821
#
#  insects :  0.02223976
#
#
# GUESS:  crickets
# [7. 8.]
# [-0.0177002  -0.02372742 -0.02700806 ... -0.04304504 -0.04063416
#  -0.03363037]
# (50, 21)
# PREDICTED VALUES
#
#  chirping_birds :  0.79657072
#
#  crickets :  0.13680482
#
#  crow :  0.00548059
#
#  frog :  0.00819921
#
#  insects :  0.05294468
#
#
# GUESS:  chirping_birds
# [8. 9.]
# [-0.01539612 -0.00108337  0.00718689 ...  0.01161194  0.01818848
#   0.02700806]
# (50, 21)
# PREDICTED VALUES
#
#  chirping_birds :  0.08781686
#
#  crickets :  0.57376772
#
#  crow :  0.17429093
#
#  frog :  0.00752130
#
#  insects :  0.15660325
#
#
# GUESS:  crickets
# [ 9. 10.]
# [ 0.03549194  0.04856873  0.05519104 ... -0.02171326 -0.03634644
#  -0.03912354]
# (50, 21)
# PREDICTED VALUES
#
#  chirping_birds :  0.09238791
#
#  crickets :  0.48944262
#
#  crow :  0.17666078
#
#  frog :  0.01202254
#
#  insects :  0.22948609
# GUESS: Nothing
# [10. 11.]
# [-0.02934265 -0.0115509   0.00445557 ... -0.03616333 -0.03759766
#  -0.0304718 ]
# (50, 21)
# PREDICTED VALUES
#
#  chirping_birds :  0.43939105
#
#  crickets :  0.30696240
#
#  crow :  0.08013844
#
#  frog :  0.01177511
#
#  insects :  0.16173299
# GUESS: Nothing
# [11. 12.]
# [-0.03358459 -0.03901672 -0.03933716 ... -0.02337646 -0.02124023
#  -0.02107239]
# (50, 21)
# PREDICTED VALUES
#
#  chirping_birds :  0.50426340
#
#  crickets :  0.44889548
#
#  crow :  0.00377538
#
#  frog :  0.00641237
#
#  insects :  0.03665335
#
#
# GUESS:  chirping_birds
# [12. 13.]
# [-0.00846863  0.00444031  0.00852966 ... -0.00604248 -0.00845337
#  -0.00497437]
# (50, 21)
# PREDICTED VALUES
#
#  chirping_birds :  0.09371475
#
#  crickets :  0.55711073
#
#  crow :  0.07205433
#
#  frog :  0.01109472
#
#  insects :  0.26602545
#
#
# GUESS:  crickets
# [13. 14.]
# [-0.00427246 -0.00718689 -0.00811768 ... -0.01966858 -0.01296997
#  -0.01628113]
# (50, 21)
# PREDICTED VALUES
#
#  chirping_birds :  0.18712001
#
#  crickets :  0.47208253
#
#  crow :  0.07959422
#
#  frog :  0.00161508
#
#  insects :  0.25958818
# GUESS: Nothing
# [14. 15.]
# [-0.02262878 -0.01573181 -0.00117493 ... -0.08956909 -0.0695343
#  -0.04067993]
# (50, 21)
# PREDICTED VALUES
#
#  chirping_birds :  0.25760078
#
#  crickets :  0.63925940
#
#  crow :  0.02965949
#
#  frog :  0.00694135
#
#  insects :  0.06653907
#
#
# GUESS:  crickets
# [15. 16.]
# [-0.02532959 -0.01031494 -0.00280762 ... -0.07128906 -0.07106018
#  -0.05839539]
# (50, 21)
# PREDICTED VALUES
#
#  chirping_birds :  0.05293163
#
#  crickets :  0.63078868
#
#  crow :  0.17786656
#
#  frog :  0.02739141
#
#  insects :  0.11102167
#
#
# GUESS:  crickets
# [16. 17.]
# [-0.04600525 -0.02149963  0.00523376 ... -0.02526855 -0.02735901
#  -0.03106689]
# (50, 21)
# PREDICTED VALUES
#
#  chirping_birds :  0.02796412
#
#  crickets :  0.11086354
#
#  crow :  0.83679360
#
#  frog :  0.00162136
#
#  insects :  0.02275736
#
#
# GUESS:  crow
# [17. 18.]
# [-0.02043152 -0.01174927 -0.02088928 ...  0.10055542  0.08653259
#   0.06604004]
# (50, 21)
# PREDICTED VALUES
#
#  chirping_birds :  0.00021679
#
#  crickets :  0.02271424
#
#  crow :  0.97008866
#
#  frog :  0.00005221
#
#  insects :  0.00692811
#
#
# GUESS:  crow
# [18. 19.]
# [ 0.04153442  0.01223755 -0.00654602 ...  0.03269958  0.02374268
#   0.02774048]
# (50, 21)
# PREDICTED VALUES
#
#  chirping_birds :  0.00002285
#
#  crickets :  0.00616124
#
#  crow :  0.99340725
#
#  frog :  0.00001823
#
#  insects :  0.00039037
#
#
# GUESS:  crow
# [19. 20.]
# [0.02185059 0.02069092 0.01451111 ... 0.03469849 0.03985596 0.04600525]
# (50, 21)
# PREDICTED VALUES
#
#  chirping_birds :  0.00008701
#
#  crickets :  0.00716705
#
#  crow :  0.99206018
#
#  frog :  0.00001256
#
#  insects :  0.00067321
#
#
# GUESS:  crow
# [20. 21.]
# [ 0.0353241   0.01567078 -0.00102234 ...  0.1058197   0.10365295
#   0.09759521]
# (50, 21)
# PREDICTED VALUES
#
#  chirping_birds :  0.00359225
#
#  crickets :  0.09355184
#
#  crow :  0.89151537
#
#  frog :  0.00015041
#
#  insects :  0.01119016
#
#
# GUESS:  crow
# [21. 22.]
# [ 0.09413147  0.07905579  0.05625916 ... -0.01145935 -0.00245667
#   0.00479126]
# (50, 21)
# PREDICTED VALUES
#
#  chirping_birds :  0.01153874
#
#  crickets :  0.08776648
#
#  crow :  0.85147232
#
#  frog :  0.01113036
#
#  insects :  0.03809211
#
#
# GUESS:  crow
# [22. 23.]
# [ 0.0037384   0.01168823  0.01628113 ... -0.03440857 -0.05511475
#  -0.08209229]
# (50, 21)
# PREDICTED VALUES
#
#  chirping_birds :  0.01195815
#
#  crickets :  0.16425838
#
#  crow :  0.78054506
#
#  frog :  0.00360085
#
#  insects :  0.03963753
#
#
# GUESS:  crow
# [23. 24.]
# [-0.1026001  -0.12590027 -0.14944458 ...  0.03462219  0.02537537
#   0.02354431]
# (50, 21)
# PREDICTED VALUES
#
#  chirping_birds :  0.00002249
#
#  crickets :  0.03304987
#
#  crow :  0.96664566
#
#  frog :  0.00000286
#
#  insects :  0.00027906
#
#
# GUESS:  crow
# [24. 25.]
# [ 0.0196991   0.02836609  0.03103638 ... -0.03009033 -0.03392029
#  -0.03681946]
# (50, 21)
# PREDICTED VALUES
#
#  chirping_birds :  0.02834702
#
#  crickets :  0.14028317
#
#  crow :  0.82185066
#
#  frog :  0.00042033
#
#  insects :  0.00909887
#
#
# GUESS:  crow
# [25. 26.]
# [-0.04151917 -0.03933716 -0.03703308 ...  0.05451965  0.0519104
#   0.05206299]
# (50, 21)
# PREDICTED VALUES
#
#  chirping_birds :  0.00808403
#
#  crickets :  0.13491529
#
#  crow :  0.84554183
#
#  frog :  0.00023027
#
#  insects :  0.01122850
#
#
# GUESS:  crow
# [26. 27.]
# [ 0.05670166  0.06253052  0.07643127 ... -0.00396729  0.00715637
#   0.00585938]
# (50, 21)
# PREDICTED VALUES
#
#  chirping_birds :  0.30382711
#
#  crickets :  0.46716243
#
#  crow :  0.02576447
#
#  frog :  0.00879143
#
#  insects :  0.19445448
# GUESS: Nothing
# [27. 28.]
# [-0.00222778 -0.01303101 -0.02310181 ...  0.01165771  0.01649475
#   0.0194397 ]
# (50, 21)
# PREDICTED VALUES
#
#  chirping_birds :  0.01908798
#
#  crickets :  0.58247250
#
#  crow :  0.36740634
#
#  frog :  0.00081965
#
#  insects :  0.03021356
#
#
# GUESS:  crickets
# [28. 29.]
# [0.01657104 0.01519775 0.00924683 ... 0.03746033 0.03282166 0.02775574]
# (50, 21)
# PREDICTED VALUES
#
#  chirping_birds :  0.29643288
#
#  crickets :  0.66599959
#
#  crow :  0.00983788
#
#  frog :  0.00168042
#
#  insects :  0.02604918
#
#
# GUESS:  crickets
# [29. 30.]
# [ 0.01919556  0.0135498   0.01724243 ... -0.00575256 -0.01502991
#  -0.02742004]
# (50, 21)
# PREDICTED VALUES
#
#  chirping_birds :  0.46157721
#
#  crickets :  0.11074462
#
#  crow :  0.33040598
#
#  frog :  0.00908794
#
#  insects :  0.08818424
# GUESS: Nothing
# [30. 31.]
# [-0.0322876  -0.0365448  -0.03544617 ... -0.0218811  -0.02978516
#  -0.04052734]
# (50, 21)
# PREDICTED VALUES
#
#  chirping_birds :  0.09439722
#
#  crickets :  0.71242911
#
#  crow :  0.16649298
#
#  frog :  0.00199924
#
#  insects :  0.02468141
#
#
# GUESS:  crickets
# [31. 32.]
# [-0.04328918 -0.03413391 -0.03421021 ...  0.05908203  0.06370544
#   0.05949402]
# (50, 21)
# PREDICTED VALUES
#
#  chirping_birds :  0.02412266
#
#  crickets :  0.36207977
#
#  crow :  0.57314396
#
#  frog :  0.00390395
#
#  insects :  0.03674959
#
#
# GUESS:  crow
# [32. 33.]
# [ 0.06063843  0.06056213  0.06610107 ... -0.12741089 -0.13371277
#  -0.12313843]
# (50, 21)
# PREDICTED VALUES
#
#  chirping_birds :  0.03494295
#
#  crickets :  0.26417795
#
#  crow :  0.63337618
#
#  frog :  0.00193922
#
#  insects :  0.06556365
#
#
# GUESS:  crow
# [33. 34.]
# [-0.09968567 -0.06376648 -0.03105164 ... -0.0138092  -0.01574707
#  -0.01896667]
# (50, 21)
# PREDICTED VALUES
#
#  chirping_birds :  0.00177779
#
#  crickets :  0.04300207
#
#  crow :  0.93167436
#
#  frog :  0.00749555
#
#  insects :  0.01605024
#
#
# GUESS:  crow
# [34. 35.]
# [-0.00811768  0.00149536  0.00953674 ... -0.004776   -0.0010376
#   0.00231934]
# (50, 21)
# PREDICTED VALUES
#
#  chirping_birds :  0.30037296
#
#  crickets :  0.10383671
#
#  crow :  0.47047505
#
#  frog :  0.01371895
#
#  insects :  0.11159633
# GUESS: Nothing
# [35. 36.]
# [ 0.00238037  0.00236511  0.00231934 ... -0.00193787  0.0068512
#   0.00695801]
# (50, 21)
# PREDICTED VALUES
#
#  chirping_birds :  0.35100570
#
#  crickets :  0.48698586
#
#  crow :  0.01208235
#
#  frog :  0.01082602
#
#  insects :  0.13910010
# GUESS: Nothing
# [{'class': 'crickets', 'timestamp': 0}, {'class': 'crickets', 'timestamp': 1}, {'class': 'Nothing', 'timestamp': 2}, {'class': 'chirping_birds', 'timestamp': 3}, {'class': 'crickets', 'timestamp': 4}, {'class': 'crickets', 'timestamp': 5}, {'class': 'crickets', 'timestamp': 6}, {'class': 'chirping_birds', 'timestamp': 7}, {'class': 'crickets', 'timestamp': 8}, {'class': 'Nothing', 'timestamp': 9}, {'class': 'Nothing', 'timestamp': 10}, {'class': 'chirping_birds', 'timestamp': 11}, {'class': 'crickets', 'timestamp': 12}, {'class': 'Nothing', 'timestamp': 13}, {'class': 'crickets', 'timestamp': 14}, {'class': 'crickets', 'timestamp': 15}, {'class': 'crow', 'timestamp': 16}, {'class': 'crow', 'timestamp': 17}, {'class': 'crow', 'timestamp': 18}, {'class': 'crow', 'timestamp': 19}, {'class': 'crow', 'timestamp': 20}, {'class': 'crow', 'timestamp': 21}, {'class': 'crow', 'timestamp': 22}, {'class': 'crow', 'timestamp': 23}, {'class': 'crow', 'timestamp': 24}, {'class': 'crow', 'timestamp': 25}, {'class': 'Nothing', 'timestamp': 26}, {'class': 'crickets', 'timestamp': 27}, {'class': 'crickets', 'timestamp': 28}, {'class': 'Nothing', 'timestamp': 29}, {'class': 'crickets', 'timestamp': 30}, {'class': 'crow', 'timestamp': 31}, {'class': 'crow', 'timestamp': 32}, {'class': 'crow', 'timestamp': 33}, {'class': 'Nothing', 'timestamp': 34}, {'class': 'Nothing', 'timestamp': 35}]
